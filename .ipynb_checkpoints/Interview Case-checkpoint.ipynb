# %% [markdown]
# <h2 style="color: green"> 1) Skriv dataene til en database med et pythonscript eller en python jupyter notebook </h2>

# %% [markdown]
# #### Database creation

# %%
# Importing libraries
import sqlite3
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import StrMethodFormatter
import seaborn as sns
# %matplotlib inline 
print("Libraries imported!")
# Out:
# Libraries imported!

# %% [markdown]
# #### I went for SQLite due to its simplicity and no need for configuration. SQLite provides GUI to import schemas easily

# %%
conn = sqlite3.connect('sparebank.db3') # if database does not exist, it will create automatically
cursor = conn.cursor()
print("Opened database successfully")
# Out:
# Opened database successfully

# %% [markdown]
# #### Reading the  files, and assign it to variable "df"

# %%
df_1 = pd.read_sql_query("SELECT * FROM TABELL_1", conn)

# %%
df_2 = pd.read_sql_query("SELECT * FROM TABELL_2", conn)

# %% [markdown]
# <hr>

# %%
# Sometimes SQLite is unstable showing tables empty, so I fetch data directly 
path_1 = "TABELL_1.txt"
path_2 = "TABELL_2.txt"
df_1 = pd.read_csv(path_1, sep='\t')
df_2 = pd.read_csv(path_2, sep='\t')

# %% [markdown]
# <hr>

# %%
print("The first 5 rows of the dataframe") 
df_1.head(5)
# Out:
# The first 5 rows of the dataframe
#      TID_ID  BK_SB1_SELSKAP_ID  KUNDE_ID  INSKUDD  UTLAN  \
# 0  20190329               2096     17466    193.0  720.0
# 1  20190329               2096     20180    339.0  643.0
# 2  20190329               2096     16879      0.0    0.0
# 3  20190329               2096      5718     48.0    0.0
# 4  20190329               2096      7364    231.0    0.0
#
#    LANGTIDSOVERVAKET_FLG  PURRING_ANTALL_12MND  LO_MEDLEM_FLG  FAM_VOKSNE_ANT  \
# 0                      0                   NaN              0             2.0
# 1                      0                   NaN              0             2.0
# 2                      0                   NaN              0             NaN
# 3                      0                   3.0              0             2.0
# 4                      0                   NaN              0             NaN
#
#    FAM_BARN_ANT  ANT_INNLOGGINGER_MOBILBANK  ANT_INNLOGGINGER_NETTBANK  \
# ...

# %%
print("The first 5 rows of the dataframe") 
df_2.head(5)
# Out:
# The first 5 rows of the dataframe
#      TID_ID  BK_SB1_SELSKAP_ID  KUNDE_ID  ALDER KJONN  DOD  KONKURS  \
# 0  20190329               2096         1      7     K    0        0
# 1  20190430               2096         1      7     K    0        0
# 2  20190430               2096        10     62     M    0        0
# 3  20190329               2096        10     62     M    0        0
# 4  20190329               2096        23     45     M    0        0
#
#   SAMTYKKE_1_SVAR SAMTYKKE_2_SVAR  HAR_EPOST  HAR_MOBIL  \
# 0               J               J          0          0
# 1               J               J          0          0
# 2               J               J          0          0
# 3               J               J          0          0
# 4               J               J          1          1
#
#   RESERVERT_MOT_MARKEDSFORING  RESERVERT_TELEFON_BRREG_FLG
# 0                           N                            0
# 1                           N                            0
# ...

# %%
print("The last 5 rows of the dataframe\n")
df_1.tail(5)
# Out:
# The last 5 rows of the dataframe
#          TID_ID  BK_SB1_SELSKAP_ID  KUNDE_ID  INSKUDD  UTLAN  \
# 41432  20190430               2096     19271      NaN    NaN
# 41433  20190329               2096      8976      NaN    NaN
# 41434  20190430               2096      1740      0.0    0.0
# 41435  20190430               2096     11946      NaN    NaN
# 41436  20190329               2096     10508      NaN    NaN
#
#        LANGTIDSOVERVAKET_FLG  PURRING_ANTALL_12MND  LO_MEDLEM_FLG  \
# 41432                      0                   NaN              0
# 41433                      0                   NaN              0
# 41434                      0                   NaN              0
# 41435                      0                   NaN              1
# 41436                      0                   NaN              0
#
#        FAM_VOKSNE_ANT  FAM_BARN_ANT  ANT_INNLOGGINGER_MOBILBANK  \
# 41432             NaN           NaN                         NaN
# ...

# %%
print("The last 5 rows of the dataframe\n")
df_2.tail(5)
# Out:
# The last 5 rows of the dataframe
#          TID_ID  BK_SB1_SELSKAP_ID  KUNDE_ID  ALDER KJONN  DOD  KONKURS  \
# 41403  20190329               2096     20891     37     K    0        0
# 41404  20190329               2096     20893     52     M    0        0
# 41405  20190430               2096     20893     52     M    0        0
# 41406  20190430               2096     20896     49     K    0        0
# 41407  20190329               2096     20896     49     K    0        0
#
#       SAMTYKKE_1_SVAR SAMTYKKE_2_SVAR  HAR_EPOST  HAR_MOBIL  \
# 41403               J               J          1          1
# 41404               J               J          1          0
# 41405               J               J          1          0
# 41406               J               J          1          1
# 41407               J               J          1          1
#
#       RESERVERT_MOT_MARKEDSFORING  RESERVERT_TELEFON_BRREG_FLG
# 41403                           N                            0
# ...

# %% [markdown]
# ## Data wrangling

# %%
# table headers in table_1
print(df_1.columns)
# Out:
# Index(['TID_ID', 'BK_SB1_SELSKAP_ID', 'KUNDE_ID', 'INSKUDD', 'UTLAN',
#        'LANGTIDSOVERVAKET_FLG', 'PURRING_ANTALL_12MND', 'LO_MEDLEM_FLG',
#        'FAM_VOKSNE_ANT', 'FAM_BARN_ANT', 'ANT_INNLOGGINGER_MOBILBANK',
#        'ANT_INNLOGGINGER_NETTBANK', 'LONNSOMHET_PER_MND'],
#       dtype='object')

# %%
# table headers in table_2
print(df_2.columns)
# Out:
# Index(['TID_ID', 'BK_SB1_SELSKAP_ID', 'KUNDE_ID', 'ALDER', 'KJONN', 'DOD',
#        'KONKURS', 'SAMTYKKE_1_SVAR', 'SAMTYKKE_2_SVAR', 'HAR_EPOST',
#        'HAR_MOBIL', 'RESERVERT_MOT_MARKEDSFORING',
#        'RESERVERT_TELEFON_BRREG_FLG'],
#       dtype='object')

# %%
# Number of rows and columns in table 1
df_1.shape
# Out:
# (41437, 13)

# %%
# Number of rows and columns in table 2
df_2.shape
# Out:
# (41408, 13)

# %%
# Checking data types
# When visualizing individual variables, it is important to first understand what type of variable you are dealing with. 
# This will help us find the right visualization method for that variable.
df_1.dtypes
# Out:
# TID_ID                          int64
# BK_SB1_SELSKAP_ID               int64
# KUNDE_ID                        int64
# INSKUDD                       float64
# UTLAN                         float64
# LANGTIDSOVERVAKET_FLG           int64
# PURRING_ANTALL_12MND          float64
# LO_MEDLEM_FLG                   int64
# FAM_VOKSNE_ANT                float64
# FAM_BARN_ANT                  float64
# ANT_INNLOGGINGER_MOBILBANK    float64
# ANT_INNLOGGINGER_NETTBANK     float64
# LONNSOMHET_PER_MND            float64
# dtype: object

# %%
# Checking data types
df_2.dtypes
# Out:
# TID_ID                          int64
# BK_SB1_SELSKAP_ID               int64
# KUNDE_ID                        int64
# ALDER                           int64
# KJONN                          object
# DOD                             int64
# KONKURS                         int64
# SAMTYKKE_1_SVAR                object
# SAMTYKKE_2_SVAR                object
# HAR_EPOST                       int64
# HAR_MOBIL                       int64
# RESERVERT_MOT_MARKEDSFORING    object
# RESERVERT_TELEFON_BRREG_FLG     int64
# dtype: object

# %% [markdown]
# #### Lets sort out by kunde_id and tid_id both tables to compare the two tables

# %%
df_1.sort_values(by=['KUNDE_ID','TID_ID'], ascending=[True,True], inplace=True)
df_1.head()
# Out:
#          TID_ID  BK_SB1_SELSKAP_ID  KUNDE_ID  INSKUDD  UTLAN  \
# 6502   20190329               2096         1     19.0    0.0
# 6580   20190430               2096         1     19.0    0.0
# 17169  20190329               2096         2    788.0    0.0
# 22042  20190430               2096         2    782.0    0.0
# 21683  20190329               2096         3     15.0    0.0
#
#        LANGTIDSOVERVAKET_FLG  PURRING_ANTALL_12MND  LO_MEDLEM_FLG  \
# 6502                       0                   NaN              0
# 6580                       0                   NaN              0
# 17169                      0                   NaN              1
# 22042                      0                   NaN              1
# 21683                      0                   NaN              0
#
#        FAM_VOKSNE_ANT  FAM_BARN_ANT  ANT_INNLOGGINGER_MOBILBANK  \
# 6502              2.0           2.0                         NaN
# 6580              2.0           2.0                         NaN
# ...

# %%
df_2.sort_values(by=['KUNDE_ID','TID_ID'], ascending=[True,True], inplace=True)
df_2.head()
# Out:
#        TID_ID  BK_SB1_SELSKAP_ID  KUNDE_ID  ALDER KJONN  DOD  KONKURS  \
# 0    20190329               2096         1      7     K    0        0
# 1    20190430               2096         1      7     K    0        0
# 144  20190329               2096         2     85     M    0        0
# 145  20190430               2096         2     85     M    0        0
# 147  20190329               2096         3     78     K    0        0
#
#     SAMTYKKE_1_SVAR SAMTYKKE_2_SVAR  HAR_EPOST  HAR_MOBIL  \
# 0                 J               J          0          0
# 1                 J               J          0          0
# 144               J               J          0          1
# 145               J               J          0          1
# 147               J               J          0          0
#
#     RESERVERT_MOT_MARKEDSFORING  RESERVERT_TELEFON_BRREG_FLG
# 0                             N                            0
# 1                             N                            0
# ...

# %% [markdown]
# #### Approximately two deposits per customer! Now let's merge the two tables on TID_ID and KUNDE_ID

# %%
df = pd.merge(df_1, df_2, on=['TID_ID', 'BK_SB1_SELSKAP_ID','KUNDE_ID'] , how='left')
df.sort_values(by=['KUNDE_ID','TID_ID'], ascending=[True,True], inplace=True)
df.head(30)
# Out:
#       TID_ID  BK_SB1_SELSKAP_ID  KUNDE_ID  INSKUDD   UTLAN  \
# 0   20190329               2096         1     19.0     0.0
# 1   20190430               2096         1     19.0     0.0
# 2   20190329               2096         2    788.0     0.0
# 3   20190430               2096         2    782.0     0.0
# 4   20190329               2096         3     15.0     0.0
# 5   20190430               2096         3      0.0     0.0
# 6   20190329               2096         4    179.0     0.0
# 7   20190430               2096         4    181.0     0.0
# 8   20190329               2096         5   1312.0     0.0
# 9   20190430               2096         5   1306.0     0.0
# 10  20190329               2096         6    132.0     0.0
# 11  20190430               2096         6    136.0     0.0
# 12  20190329               2096         7    476.0     0.0
# 13  20190430               2096         7    474.0     0.0
# 14  20190329               2096         8     11.0   222.0
# ...

# %%
# Number of columans and rows
df.shape
# Out:
# (41437, 23)

# %% [markdown]
# #### Number of missing values:

# %%
#df_1..isnull().values.any() 
df.isnull().sum()
# Out:
# TID_ID                             0
# BK_SB1_SELSKAP_ID                  0
# KUNDE_ID                           0
# INSKUDD                         5075
# UTLAN                           5075
# LANGTIDSOVERVAKET_FLG              0
# PURRING_ANTALL_12MND           36779
# LO_MEDLEM_FLG                      0
# FAM_VOKSNE_ANT                 21105
# FAM_BARN_ANT                   21105
# ANT_INNLOGGINGER_MOBILBANK     12182
# ANT_INNLOGGINGER_NETTBANK      12182
# LONNSOMHET_PER_MND              7143
# ALDER                             29
# KJONN                             47
# DOD                               29
# KONKURS                           29
# SAMTYKKE_1_SVAR                  256
# SAMTYKKE_2_SVAR                   29
# HAR_EPOST                         29
# HAR_MOBIL                         29
# RESERVERT_MOT_MARKEDSFORING      226
# RESERVERT_TELEFON_BRREG_FLG       29
# dtype: int64

# %%
print("The number of unique client IDs:")
df['KUNDE_ID'].nunique()
# Out:
# The number of unique client IDs:
# 20822

# %% [markdown]
# #### Too many missing values in table 1! Drop or impute? Of course, we may replace the missing values by sampling of non-missing values. But here for simplicity, I will replace them either with mean or mode.

# %%
df.columns
# Out:
# Index(['TID_ID', 'BK_SB1_SELSKAP_ID', 'KUNDE_ID', 'INSKUDD', 'UTLAN',
#        'LANGTIDSOVERVAKET_FLG', 'PURRING_ANTALL_12MND', 'LO_MEDLEM_FLG',
#        'FAM_VOKSNE_ANT', 'FAM_BARN_ANT', 'ANT_INNLOGGINGER_MOBILBANK',
#        'ANT_INNLOGGINGER_NETTBANK', 'LONNSOMHET_PER_MND', 'ALDER', 'KJONN',
#        'DOD', 'KONKURS', 'SAMTYKKE_1_SVAR', 'SAMTYKKE_2_SVAR', 'HAR_EPOST',
#        'HAR_MOBIL', 'RESERVERT_MOT_MARKEDSFORING',
#        'RESERVERT_TELEFON_BRREG_FLG'],
#       dtype='object')

# %% [markdown]
# ### Visualisation

# %%
df.hist(column='LONNSOMHET_PER_MND')
df.hist(column='INSKUDD')
df.hist(column='UTLAN')
df.hist(column='PURRING_ANTALL_12MND')
df.hist(column='FAM_VOKSNE_ANT')
df.hist(column='FAM_BARN_ANT')
df.hist(column='ANT_INNLOGGINGER_MOBILBANK')
df.hist(column='ANT_INNLOGGINGER_NETTBANK')
df.hist(column='ALDER')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000019AC70D11D0>]],
#       dtype=object)

# %%
boxplot = df.boxplot(column=['INSKUDD', 'UTLAN'], by='KJONN', layout=(2, 1), figsize=(12, 10))

# %%
print("Replaced with average:")
print("")
AVG_INSKUDD = df["INSKUDD"].astype("float").mean(axis=0)
print("Average deposit:", AVG_INSKUDD)
df["INSKUDD"].replace(np.nan, AVG_INSKUDD, inplace=True)

AVG_UTLAN = df['UTLAN'].astype('float').mean(axis=0)
print("Average loan:", AVG_UTLAN)
df["UTLAN"].replace(np.nan, AVG_UTLAN, inplace=True)

AVG_LONNSOMHET_PER_MND = df['LONNSOMHET_PER_MND'].astype('float').mean(axis=0)
print("Average profitability:", AVG_LONNSOMHET_PER_MND)
df["LONNSOMHET_PER_MND"].replace(np.nan, AVG_LONNSOMHET_PER_MND, inplace=True)
# Out:
# Replaced with average:
#
# Average deposit: 190.53660414718664
# Average loan: 422.60150706781803
# Average profitability: 669.9195194494664

# %%
print("Replaced the rest with mode")
df['PURRING_ANTALL_12MND'].fillna(df['PURRING_ANTALL_12MND'].mode()[0], inplace=True)

df['FAM_VOKSNE_ANT'].fillna(df['FAM_VOKSNE_ANT'].mode()[0], inplace=True)

df['FAM_BARN_ANT'].fillna(df['FAM_BARN_ANT'].mode()[0], inplace=True)

df['ANT_INNLOGGINGER_MOBILBANK'].fillna(df['ANT_INNLOGGINGER_MOBILBANK'].mode()[0], inplace=True)

df['ANT_INNLOGGINGER_NETTBANK'].fillna(df['ANT_INNLOGGINGER_NETTBANK'].mode()[0], inplace=True)

df['ALDER'].fillna(df['ALDER'].mode()[0], inplace=True)

df['KJONN'].fillna(df['KJONN'].mode()[0], inplace=True)

df['DOD'].fillna(df['DOD'].mode()[0], inplace=True)

df['KONKURS'].fillna(df['KONKURS'].mode()[0], inplace=True)

df['SAMTYKKE_1_SVAR'].fillna(df['SAMTYKKE_1_SVAR'].mode()[0], inplace=True)

df['SAMTYKKE_2_SVAR'].fillna(df['SAMTYKKE_2_SVAR'].mode()[0], inplace=True)

df['HAR_EPOST'].fillna(df['HAR_EPOST'].mode()[0], inplace=True)

df['HAR_MOBIL'].fillna(df['HAR_MOBIL'].mode()[0], inplace=True)

df['RESERVERT_MOT_MARKEDSFORING'].fillna(df['RESERVERT_MOT_MARKEDSFORING'].mode()[0], inplace=True)

df['RESERVERT_TELEFON_BRREG_FLG'].fillna(df['RESERVERT_TELEFON_BRREG_FLG'].mode()[0], inplace=True)
# Out:
# Replaced the rest with mode

# %%
print("Missing values? Replaced successfully!")
df.isnull().sum()
# Out:
# Missing values? Replaced successfully!
# TID_ID                         0
# BK_SB1_SELSKAP_ID              0
# KUNDE_ID                       0
# INSKUDD                        0
# UTLAN                          0
# LANGTIDSOVERVAKET_FLG          0
# PURRING_ANTALL_12MND           0
# LO_MEDLEM_FLG                  0
# FAM_VOKSNE_ANT                 0
# FAM_BARN_ANT                   0
# ANT_INNLOGGINGER_MOBILBANK     0
# ANT_INNLOGGINGER_NETTBANK      0
# LONNSOMHET_PER_MND             0
# ALDER                          0
# KJONN                          0
# DOD                            0
# KONKURS                        0
# SAMTYKKE_1_SVAR                0
# SAMTYKKE_2_SVAR                0
# HAR_EPOST                      0
# HAR_MOBIL                      0
# RESERVERT_MOT_MARKEDSFORING    0
# RESERVERT_TELEFON_BRREG_FLG    0
# dtype: int64

# %% [markdown]
# #### Let's convert data types to proper format

# %%
df.dtypes
# Out:
# TID_ID                           int64
# BK_SB1_SELSKAP_ID                int64
# KUNDE_ID                         int64
# INSKUDD                        float64
# UTLAN                          float64
# LANGTIDSOVERVAKET_FLG            int64
# PURRING_ANTALL_12MND           float64
# LO_MEDLEM_FLG                    int64
# FAM_VOKSNE_ANT                 float64
# FAM_BARN_ANT                   float64
# ANT_INNLOGGINGER_MOBILBANK     float64
# ANT_INNLOGGINGER_NETTBANK      float64
# LONNSOMHET_PER_MND             float64
# ALDER                          float64
# KJONN                           object
# DOD                            float64
# KONKURS                        float64
# SAMTYKKE_1_SVAR                 object
# SAMTYKKE_2_SVAR                 object
# HAR_EPOST                      float64
# HAR_MOBIL                      float64
# RESERVERT_MOT_MARKEDSFORING     object
# RESERVERT_TELEFON_BRREG_FLG    float64
# dtype: object

# %% [markdown]
# #### Some variables simply cannot be float / decimal, so will be converted into integers, 1 or 0

# %%
df[["PURRING_ANTALL_12MND","FAM_VOKSNE_ANT","FAM_BARN_ANT",
   "ANT_INNLOGGINGER_MOBILBANK","ANT_INNLOGGINGER_NETTBANK","ALDER","DOD", "KONKURS","HAR_EPOST",
    "HAR_MOBIL","RESERVERT_TELEFON_BRREG_FLG"]] = df[["PURRING_ANTALL_12MND","FAM_VOKSNE_ANT",
    "FAM_BARN_ANT","ANT_INNLOGGINGER_MOBILBANK","ANT_INNLOGGINGER_NETTBANK",
    "ALDER","DOD", "KONKURS","HAR_EPOST", "HAR_MOBIL","RESERVERT_TELEFON_BRREG_FLG"]].astype("int")

# %% [markdown]
# #### While some variables should be standardized by converting into binary from categorical

# %%
df['RESERVERT_MOT_MARKEDSFORING'].value_counts()
# Out:
# N    41064
# J      373
# Name: RESERVERT_MOT_MARKEDSFORING, dtype: int64

# %%
#df.replace("?", np.nan, inplace = True)
df['RESERVERT_MOT_MARKEDSFORING'].replace('N', 0, inplace = True)
df['RESERVERT_MOT_MARKEDSFORING'].replace('J', 1, inplace = True)
print(df['RESERVERT_MOT_MARKEDSFORING'].dtypes)
# Out:
# int64

# %%
df['SAMTYKKE_1_SVAR'].replace('N', 0, inplace = True)
df['SAMTYKKE_1_SVAR'].replace('J', 1, inplace = True)
print(df['SAMTYKKE_1_SVAR'].dtypes)
# Out:
# int64

# %%
df['SAMTYKKE_2_SVAR'].replace('N', 0, inplace = True)
df['SAMTYKKE_2_SVAR'].replace('J', 1, inplace = True)
print(df['SAMTYKKE_2_SVAR'].dtypes)
# Out:
# int64

# %%
df['KJONN'].replace('K', 0, inplace = True)
df['KJONN'].replace('M', 1, inplace = True)
print(df['KJONN'].dtypes)
# Out:
# int64

# %%
df.head(30)
# Out:
#       TID_ID  BK_SB1_SELSKAP_ID  KUNDE_ID      INSKUDD        UTLAN  \
# 0   20190329               2096         1    19.000000     0.000000
# 1   20190430               2096         1    19.000000     0.000000
# 2   20190329               2096         2   788.000000     0.000000
# 3   20190430               2096         2   782.000000     0.000000
# 4   20190329               2096         3    15.000000     0.000000
# 5   20190430               2096         3     0.000000     0.000000
# 6   20190329               2096         4   179.000000     0.000000
# 7   20190430               2096         4   181.000000     0.000000
# 8   20190329               2096         5  1312.000000     0.000000
# 9   20190430               2096         5  1306.000000     0.000000
# 10  20190329               2096         6   132.000000     0.000000
# 11  20190430               2096         6   136.000000     0.000000
# 12  20190329               2096         7   476.000000     0.000000
# ...

# %%
df.dtypes
# Out:
# TID_ID                           int64
# BK_SB1_SELSKAP_ID                int64
# KUNDE_ID                         int64
# INSKUDD                        float64
# UTLAN                          float64
# LANGTIDSOVERVAKET_FLG            int64
# PURRING_ANTALL_12MND             int32
# LO_MEDLEM_FLG                    int64
# FAM_VOKSNE_ANT                   int32
# FAM_BARN_ANT                     int32
# ANT_INNLOGGINGER_MOBILBANK       int32
# ANT_INNLOGGINGER_NETTBANK        int32
# LONNSOMHET_PER_MND             float64
# ALDER                            int32
# KJONN                            int64
# DOD                              int32
# KONKURS                          int32
# SAMTYKKE_1_SVAR                  int64
# SAMTYKKE_2_SVAR                  int64
# HAR_EPOST                        int32
# HAR_MOBIL                        int32
# RESERVERT_MOT_MARKEDSFORING      int64
# RESERVERT_TELEFON_BRREG_FLG      int32
# dtype: object

# %% [markdown]
# <hr>

# %% [markdown]
# #### We could aggregate transactions with the same KUNDE_ID by the following code. The results will be identical. Since no customer has 100% identical transaction, and we will drop variables like KUNDE_ID multicollinearity should not be a problem. Furthermore, there is no point to reduce our data size by aggregation and since we do not know how 'LONNSOMHET_PER_MND' is exactly calculated, there is a risk for us to just sum up 'LONNSOMHET_PER_MND' for the same customer with the same ID:
# While aggregating age is problematic, the same client got birthday on the day data collected which would produce two different clients if we grouped by alltogether. So, we have to group by 'alder' and the rest separately and then merge two tables

# %% [raw]
# # PROBLEMATIC WITH AGE
#
# df_grouped=df.groupby(['KUNDE_ID','LANGTIDSOVERVAKET_FLG','LO_MEDLEM_FLG','FAM_VOKSNE_ANT','FAM_BARN_ANT','ALDER',
#                        'DOD','KONKURS','HAR_EPOST','HAR_MOBIL','RESERVERT_MOT_MARKEDSFORING','RESERVERT_TELEFON_BRREG_FLG',
#                        'KJONN'])[['INSKUDD','UTLAN','LONNSOMHET_PER_MND','PURRING_ANTALL_12MND',
#                                           'ANT_INNLOGGINGER_MOBILBANK','ANT_INNLOGGINGER_NETTBANK']].sum()
# df_grouped.tail(30)

# %% [raw]
# df_grouped_1=df.groupby(['KUNDE_ID','LANGTIDSOVERVAKET_FLG','LO_MEDLEM_FLG','FAM_VOKSNE_ANT','FAM_BARN_ANT',
#                        'DOD','KONKURS','HAR_EPOST','HAR_MOBIL','RESERVERT_MOT_MARKEDSFORING','RESERVERT_TELEFON_BRREG_FLG',
#                        'KJONN'])[['INSKUDD','UTLAN','LONNSOMHET_PER_MND','PURRING_ANTALL_12MND',
#                                           'ANT_INNLOGGINGER_MOBILBANK','ANT_INNLOGGINGER_NETTBANK']].sum()
# df_grouped_1.tail()

# %% [raw]
# df_grouped_2=df.groupby('KUNDE_ID')[['ALDER']].mean()
# df_grouped_2.tail()

# %% [raw]
# df_grouped_1.shape

# %% [raw]
# df_grouped_2.shape

# %% [raw]
# # merge two tables
# df = pd.merge(df_grouped_1, df_grouped_2, on=['KUNDE_ID'] , how='inner')
# df.sort_values(by=['KUNDE_ID'], ascending=[True], inplace=True)
#
# # Rounding the age since 'mean' produces float
# df[["ALDER"]] = df[["ALDER"]].astype("int")
# df.head()

# %% [raw]
# df.shape

# %% [markdown]
# <hr>

# %% [markdown]
# <h2 style="color: green"> 2) Hvordan ser lønnsomme kunder ut? </h2>
# 	- Visualisering
# 	- Korrelasjon
# 	- Lineær regresjon eller andre gjennomsiktige metoder

# %% [markdown]
# ### Correlation

# %%
df[[ 'LONNSOMHET_PER_MND','INSKUDD', 'UTLAN',
       'LANGTIDSOVERVAKET_FLG', 'PURRING_ANTALL_12MND', 'LO_MEDLEM_FLG',
       'FAM_VOKSNE_ANT', 'FAM_BARN_ANT', 'ANT_INNLOGGINGER_MOBILBANK',
       'ANT_INNLOGGINGER_NETTBANK', 'LONNSOMHET_PER_MND', 'ALDER', 'KJONN',
       'DOD', 'KONKURS', 'HAR_EPOST',
       'HAR_MOBIL', 'RESERVERT_MOT_MARKEDSFORING',
       'RESERVERT_TELEFON_BRREG_FLG']].corr()
# Out:
#                              LONNSOMHET_PER_MND   INSKUDD     UTLAN  \
# LONNSOMHET_PER_MND                     1.000000  0.344591  0.573137
# INSKUDD                                0.344591  1.000000  0.002907
# UTLAN                                  0.573137  0.002907  1.000000
# LANGTIDSOVERVAKET_FLG                  0.023564 -0.020005 -0.006185
# PURRING_ANTALL_12MND                   0.152359 -0.035055  0.127379
# LO_MEDLEM_FLG                          0.043705  0.019508  0.045404
# FAM_VOKSNE_ANT                         0.019967  0.045070  0.000922
# FAM_BARN_ANT                          -0.013959 -0.087743  0.062859
# ANT_INNLOGGINGER_MOBILBANK             0.042015 -0.059106  0.128563
# ANT_INNLOGGINGER_NETTBANK              0.076737  0.037385  0.055673
# LONNSOMHET_PER_MND                     1.000000  0.344591  0.573137
# ALDER                                  0.175668  0.237471 -0.005588
# KJONN                                  0.114651  0.014663  0.153576
# ...

# %% [markdown]
# ### Visualisation

# %% [markdown]
# ####  'LONNSOMHET_PER_MND' has black swans! Negative numbers in >0.02 quantiles

# %%
# Quantiles
df['LONNSOMHET_PER_MND'].quantile(np.arange(0, 1, 0.01))
# Out:
# 0.00   -68195.000000
# 0.01      -56.000000
# 0.02        0.000000
# 0.03        0.000000
# 0.04        0.000000
# 0.05        0.000000
# 0.06        0.000000
# 0.07        1.000000
# 0.08        2.000000
# 0.09        4.000000
# 0.10        6.000000
# 0.11        8.000000
# 0.12       10.000000
# 0.13       12.000000
# 0.14       15.000000
# 0.15       17.000000
# 0.16       20.000000
# 0.17       24.000000
# 0.18       27.000000
# 0.19       31.000000
# 0.20       35.000000
# 0.21       39.000000
# 0.22       45.000000
# 0.23       50.000000
# 0.24       56.000000
# 0.25       63.000000
# 0.26       70.000000
# 0.27       77.000000
# 0.28       85.000000
# 0.29       94.000000
#             ...
# 0.70      669.919519
# 0.71      669.919519
# 0.72      669.919519
# 0.73      669.919519
# 0.74      676.280000
# 0.75      716.000000
# 0.76      754.000000
# 0.77      797.000000
# 0.78      843.000000
# 0.79      889.000000
# 0.80      940.000000
# 0.81      990.160000
# ...

# %%
df['LONNSOMHET_PER_MND'].plot(kind='box', figsize=(10, 7))

plt.title('LONNSOMHET_PER_MND')
#plt.xlabel('LONNSOMHET_PER_MND')

plt.show()

# %% [markdown]
# ### Regression

# %%
# X as a predictor variable of y
sns.regplot(x="INSKUDD", y="LONNSOMHET_PER_MND", data=df)

# %%
# X as a predictor variable of y
sns.regplot(x="UTLAN", y="LONNSOMHET_PER_MND", data=df)

# %% [markdown]
# <h2 style="color: green">3) Hvordan ser kunder som øker lønnsomheten ut? Finn topp 100 kunder som kommer til å få økt lønnsomheten på siste tid. </h2>
# 	- Segmentering eller clustering
# 	- Prediksjon (besluttningstree, nevrale nett, lineær regresjon, ..)

# %%
df.columns
# Out:
# Index(['TID_ID', 'BK_SB1_SELSKAP_ID', 'KUNDE_ID', 'INSKUDD', 'UTLAN',
#        'LANGTIDSOVERVAKET_FLG', 'PURRING_ANTALL_12MND', 'LO_MEDLEM_FLG',
#        'FAM_VOKSNE_ANT', 'FAM_BARN_ANT', 'ANT_INNLOGGINGER_MOBILBANK',
#        'ANT_INNLOGGINGER_NETTBANK', 'LONNSOMHET_PER_MND', 'ALDER', 'KJONN',
#        'DOD', 'KONKURS', 'SAMTYKKE_1_SVAR', 'SAMTYKKE_2_SVAR', 'HAR_EPOST',
#        'HAR_MOBIL', 'RESERVERT_MOT_MARKEDSFORING',
#        'RESERVERT_TELEFON_BRREG_FLG'],
#       dtype='object')

# %%
def tran(x):
    if x <= 0:
        return 'Bad'
    if x > 0:
        return 'Good'

# %%
df['LONNSOMHET_PER_MND_TYPE'] = df['LONNSOMHET_PER_MND'].apply(tran)
print("Bad customer: 0 Good customer: 1")
df.head(10)
# Out:
# Bad customer: 0 Good customer: 1
#      TID_ID  BK_SB1_SELSKAP_ID  KUNDE_ID  INSKUDD  UTLAN  \
# 0  20190329               2096         1     19.0    0.0
# 1  20190430               2096         1     19.0    0.0
# 2  20190329               2096         2    788.0    0.0
# 3  20190430               2096         2    782.0    0.0
# 4  20190329               2096         3     15.0    0.0
# 5  20190430               2096         3      0.0    0.0
# 6  20190329               2096         4    179.0    0.0
# 7  20190430               2096         4    181.0    0.0
# 8  20190329               2096         5   1312.0    0.0
# 9  20190430               2096         5   1306.0    0.0
#
#    LANGTIDSOVERVAKET_FLG  PURRING_ANTALL_12MND  LO_MEDLEM_FLG  FAM_VOKSNE_ANT  \
# 0                      0                     0              0               2
# 1                      0                     0              0               2
# ...

# %% [markdown]
# #### Lets look at the distribution of the customer type based on loans and deposits:

# %%
ax = df[df['LONNSOMHET_PER_MND_TYPE'] == 'Good'].plot(kind='scatter', x='UTLAN', y='INSKUDD', color='green', label='Good');
df[df['LONNSOMHET_PER_MND_TYPE'] == 'Bad'].plot(kind='scatter', x='UTLAN', y='INSKUDD', color='red', label='Bad', ax=ax);
plt.show()

# %% [markdown]
# #### How many profitable and unprofitable customers we have: Total 812

# %%
print("Women: 0 Men: 1")
df.groupby(['KJONN'])['LONNSOMHET_PER_MND_TYPE'].value_counts(normalize=False)
# Out:
# Women: 0 Men: 1
# KJONN  LONNSOMHET_PER_MND_TYPE
# 0      Good                       18685
#        Bad                         1257
# 1      Good                       20020
#        Bad                         1475
# Name: LONNSOMHET_PER_MND_TYPE, dtype: int64

# %% [markdown]
# #### Dropping unnecessary columns for further analysis

# %%
df.columns
# Out:
# Index(['TID_ID', 'BK_SB1_SELSKAP_ID', 'KUNDE_ID', 'INSKUDD', 'UTLAN',
#        'LANGTIDSOVERVAKET_FLG', 'PURRING_ANTALL_12MND', 'LO_MEDLEM_FLG',
#        'FAM_VOKSNE_ANT', 'FAM_BARN_ANT', 'ANT_INNLOGGINGER_MOBILBANK',
#        'ANT_INNLOGGINGER_NETTBANK', 'LONNSOMHET_PER_MND', 'ALDER', 'KJONN',
#        'DOD', 'KONKURS', 'SAMTYKKE_1_SVAR', 'SAMTYKKE_2_SVAR', 'HAR_EPOST',
#        'HAR_MOBIL', 'RESERVERT_MOT_MARKEDSFORING',
#        'RESERVERT_TELEFON_BRREG_FLG', 'LONNSOMHET_PER_MND_TYPE'],
#       dtype='object')

# %% [raw]
# # run if you aggregated data above
# data = df.drop(['LONNSOMHET_PER_MND','ANT_INNLOGGINGER_MOBILBANK', 'ANT_INNLOGGINGER_NETTBANK'], axis=1)
# data.head()

# %%
data = df.drop(['TID_ID','BK_SB1_SELSKAP_ID','KUNDE_ID','LONNSOMHET_PER_MND','ANT_INNLOGGINGER_MOBILBANK',
                'ANT_INNLOGGINGER_NETTBANK','LO_MEDLEM_FLG','LANGTIDSOVERVAKET_FLG', 'DOD', 'KONKURS',
                'SAMTYKKE_1_SVAR', 'SAMTYKKE_2_SVAR','HAR_EPOST','RESERVERT_MOT_MARKEDSFORING',
                'RESERVERT_TELEFON_BRREG_FLG','FAM_VOKSNE_ANT', 'FAM_BARN_ANT'], axis=1)
data.head()
# Out:
#    INSKUDD  UTLAN  PURRING_ANTALL_12MND  ALDER  KJONN  HAR_MOBIL  \
# 0     19.0    0.0                     0      7      0          0
# 1     19.0    0.0                     0      7      0          0
# 2    788.0    0.0                     0     85      1          1
# 3    782.0    0.0                     0     85      1          1
# 4     15.0    0.0                     0     78      0          0
#
#   LONNSOMHET_PER_MND_TYPE
# 0                    Good
# 1                    Good
# 2                    Good
# 3                    Good
# 4                    Good

# %% [markdown]
# ### Modelling (Logistic Regression with Scikit-learn)

# %%
X = np.asarray(data[['INSKUDD', 'UTLAN', 'PURRING_ANTALL_12MND', 'ALDER', 'KJONN', 'HAR_MOBIL']])
X[0:5]
# Out:
# array([[ 19.,   0.,   0.,   7.,   0.,   0.],
#        [ 19.,   0.,   0.,   7.,   0.,   0.],
#        [788.,   0.,   0.,  85.,   1.,   1.],
#        [782.,   0.,   0.,  85.,   1.,   1.],
#        [ 15.,   0.,   0.,  78.,   0.,   0.]])

# %%
y = np.asarray(data['LONNSOMHET_PER_MND_TYPE'].values)
y [0:5]
# Out:
# array(['Good', 'Good', 'Good', 'Good', 'Good'], dtype=object)

# %% [markdown]
# #### Also, we normalize the dataset:

# %%
from sklearn import preprocessing
X = preprocessing.StandardScaler().fit(X).transform(X)

#from sklearn.preprocessing import StandardScaler
#X = StandardScaler().fit_transform(X)
X[0:5]
# Out:
# array([[-0.35, -0.45, -0.12, -1.85, -1.04, -2.09],
#        [-0.35, -0.45, -0.12, -1.85, -1.04, -2.09],
#        [ 1.22, -0.45, -0.12,  1.89,  0.96,  0.48],
#        [ 1.21, -0.45, -0.12,  1.89,  0.96,  0.48],
#        [-0.36, -0.45, -0.12,  1.56, -1.04, -2.09]])

# %% [markdown]
# ## Classification
# - Logistic Regression
# - K Nearest Neighbor(KNN)
# - Decision Tree
# - Support Vector Machine

# %% [markdown]
# #### Train/Test dataset

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# #### Try this batch if you want to divided just into two, train and test sets

# %% [raw]
# from sklearn.model_selection import train_test_split
# X_train, X_test, y_train, y_test = train_test_split( X, y, test_size = 0.2, random_state = 4)
# print ('Train set:', X_train.shape,  y_train.shape)
# print ('Test set:', X_test.shape,  y_test.shape)
# print("We split our dataset into train and test set first: 80% / 20%")

# %% [markdown]
# #### If we want to further validate the model, then the data can be split into 3 instead of two as above. First to split to train, test and then split train again into validation and train. That way can we map out for example top 100 customer with highest probabilities to labels - KUNDE_ID. Since we do not have extra validation data, that is the way to go. Or, we can manually take some part of the original data for validation

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=1)
    
print("We split our dataset into val, test. 60%, 20%, 20% of the dataset respectively.")
# Out:
# We split our dataset into val, test. 60%, 20%, 20% of the dataset respectively.

# %% [markdown]
# <hr>

# %% [markdown]
# ## Logistic Regression

# %% [markdown]
# The version of Logistic Regression in Scikit-learn, support regularization. Regularization is a technique used to solve the overfitting problem in machine learning models.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
LR = LogisticRegression(C=0.01, solver='liblinear').fit(X_train, y_train) # may try 'sa' instead of 'liblinear' as well
LR
# Out:
# LogisticRegression(C=0.01, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %% [markdown]
# Now we can predict using our test set:

# %%
yhat = LR.predict(X_test)
yhat
# Out:
# array(['Good', 'Good', 'Good', ..., 'Good', 'Good', 'Good'], dtype=object)

# %% [markdown]
# __predict_proba__  returns estimates for all classes, ordered by the label of classes. So, the first column is the probability of class 1, P(Y=1|X), and second column is probability of class 0, P(Y=0|X):

# %%
yhat_prob = LR.predict_proba(X_test)
yhat_prob
# Out:
# array([[0.04, 0.96],
#        [0.09, 0.91],
#        [0.12, 0.88],
#        ...,
#        [0.15, 0.85],
#        [0.18, 0.82],
#        [0.13, 0.87]])

# %%
# Let us print out X-set vs predicted together
for i in range(len(X_test)):
    print("X=%s, Predicted=%s" % (X_test[i], yhat_prob[i]))
# Out:
# X=[ 0.01 -0.45 -0.12  1.32  0.96  0.48], Predicted=[0.04 0.96]
# X=[-0.39 -0.44 -0.12 -0.22 -1.04  0.48], Predicted=[0.09 0.91]
# X=[-0.39 -0.45 -0.12 -1.04 -1.04  0.48], Predicted=[0.12 0.88]
# X=[ 0.09 -0.45 -0.12  1.03 -1.04  0.48], Predicted=[0.04 0.96]
# X=[-0.39  1.79  7.33 -0.8   0.96  0.48], Predicted=[0.04 0.96]
# X=[ 0.51 -0.45 -0.12  1.99  0.96  0.48], Predicted=[0.02 0.98]
# X=[ 5.79e-17 -6.02e-17 -1.24e-01  2.12e-01  9.63e-01  4.79e-01], Predicted=[0.06 0.94]
# X=[ 5.79e-17 -6.02e-17 -1.24e-01  8.36e-01 -1.04e+00  4.79e-01], Predicted=[0.04 0.96]
# X=[-0.39 -0.45 -0.12  0.4  -1.04  0.48], Predicted=[0.07 0.93]
# X=[-0.22 -0.45 -0.12 -1.18  0.96  0.48], Predicted=[0.13 0.87]
# X=[-0.1   1.77  3.6   0.64  0.96  0.48], Predicted=[0.02 0.98]
# X=[-0.39 -0.45 -0.12 -0.03 -1.04  0.48], Predicted=[0.08 0.92]
# X=[-0.37  1.37 -0.12 -0.7   0.96  0.48], Predicted=[0.06 0.94]
# X=[-0.12 -0.45 -0.12 -1.71 -1.04 -2.09], Predicted=[0.16 0.84]
# ...

# %% [markdown]
# ### Evaluation

# %% [markdown]
# #### jaccard index
# Lets try jaccard index for accuracy evaluation. we can define jaccard as the size of the intersection divided by the size of the union of two label sets. If the entire set of predicted labels for a sample strictly match with the true set of labels, then the subset accuracy is 1.0; otherwise it is 0.0.

# %%
from sklearn.metrics import jaccard_similarity_score
jaccard_similarity_score(y_test, yhat)
# Out:
# 0.9338803088803089

# %% [markdown]
# #### confusion matrix
# Another way of looking at accuracy of classifier is to look at __confusion matrix__.

# %%
from sklearn.metrics import classification_report, confusion_matrix
import itertools
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
print(confusion_matrix(y_test, yhat, labels=['Good','Bad']))
# Out:
# [[7740    0]
#  [ 548    0]]

# %%
# Compute confusion matrix
cnf_matrix = confusion_matrix(y_test, yhat, labels=['Good','Bad'])
np.set_printoptions(precision=2)


# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=['Good=1','Bad=0'],normalize= False,  title='Confusion matrix')
# Out:
# Confusion matrix, without normalization
# [[7740    0]
#  [ 548    0]]

# %% [markdown]
# We can interpret these numbers as the count of true positives, false positives, true negatives, and false negatives.

# %%
print (classification_report(y_test, yhat))
# Out:
#              precision    recall  f1-score   support
#
#         Bad       0.00      0.00      0.00       548
#        Good       0.93      1.00      0.97      7740
#
# avg / total       0.87      0.93      0.90      8288
# C:\Users\Alizamin\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# Based on the count of each section, we can calculate precision and recall of each label:
#
#
# - __Precision__ is a measure of the accuracy provided that a class label has been predicted. It is defined by: precision = TP / (TP + FP)
#
# - __Recall__ is true positive rate. It is defined as: Recall =  TP / (TP + FN)
#
#
# So, we can calculate precision and recall of each class.
#
# __F1 score:__
# Now we are in the position to calculate the F1 scores for each label based on the precision and recall of that label.
#
# The F1 score is the harmonic average of the precision and recall, where an F1 score reaches its best value at 1 (perfect precision and recall) and worst at 0. It is a good way to show that a classifer has a good value for both recall and precision.

# %% [markdown]
# #### log loss
# Now, lets try __log loss__ for evaluation. In logistic regression, the output can be the probability of customer type is good (or equals to 1). This probability is a value between 0 and 1.
# Log loss( Logarithmic loss) measures the performance of a classifier where the predicted output is a probability value between 0 and 1.

# %%
from sklearn.metrics import log_loss
log_loss(y_test, yhat_prob)
# Out:
# 0.22616432650397303

# %% [markdown]
# <hr>

# %% [markdown]
# ## K Nearest Neighbor(KNN)

# %%
from sklearn.neighbors import KNeighborsClassifier

# let´s try with k = 4
k = 4
#Train Model and Predict  
neigh = KNeighborsClassifier(n_neighbors = k).fit(X_train,y_train)
neigh
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=4, p=2,
#            weights='uniform')

# %%
yhat = neigh.predict(X_test)
yhat[0:5]
# Out:
# array(['Good', 'Good', 'Bad', 'Good', 'Good'], dtype=object)

# %%
from sklearn import metrics
print("Train set Accuracy: ", metrics.accuracy_score(y_train, neigh.predict(X_train)))
print("Test set Accuracy: ", metrics.accuracy_score(y_test, yhat))
# Out:
# Train set Accuracy:  0.9342358309136846
# Test set Accuracy:  0.913730694980695

# %%
# k = 6
k = 6
neigh6 = KNeighborsClassifier(n_neighbors = k).fit(X_train,y_train)
yhat6 = neigh6.predict(X_test)
print("Train set Accuracy: ", metrics.accuracy_score(y_train, neigh6.predict(X_train)))
print("Test set Accuracy: ", metrics.accuracy_score(y_test, yhat6))
# Out:
# Train set Accuracy:  0.9344620837889814
# Test set Accuracy:  0.9224179536679536

# %%
# all other Ks
Ks = 14
mean_acc = np.zeros((Ks-1))
std_acc = np.zeros((Ks-1))
ConfustionMx = [];
for n in range(1,Ks):
    
    # Train Model and Predict  
    neigh = KNeighborsClassifier(n_neighbors = n).fit(X_train,y_train)
    yhat=neigh.predict(X_test)
    mean_acc[n-1] = metrics.accuracy_score(y_test, yhat)    
    std_acc[n-1]=np.std(yhat==y_test)/np.sqrt(yhat.shape[0])

mean_acc
# Out:
# array([0.92, 0.9 , 0.92, 0.91, 0.93, 0.92, 0.93, 0.93, 0.93, 0.93, 0.93,
#        0.93, 0.93])

# %%
# plotting number of ks vs model accuracy
plt.plot(range(1,Ks),mean_acc,'g')
plt.fill_between(range(1,Ks),mean_acc - 1 * std_acc,mean_acc + 1 * std_acc, alpha=0.10)
plt.legend(('Accuracy ', '+/- 3xstd'))
plt.ylabel('Accuracy ')
plt.xlabel('Number of Nabors (K)')
plt.tight_layout()
plt.show()

# the best model
print( "The best accuracy was with", mean_acc.max(), "with k=", mean_acc.argmax()+1)
# Out:
# The best accuracy was with 0.9314671814671814 with k= 13

# %%
#F-1 score
from sklearn.metrics import f1_score
f1_score(y_test, yhat, average='weighted')
# Out:
# 0.9188585989186426

# %%
#jaccard index
from sklearn.metrics import jaccard_similarity_score
jaccard_similarity_score(y_test, yhat)
# Out:
# 0.9314671814671814

# %% [markdown]
# <hr>

# %% [markdown]
# ## Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
decisionTree = DecisionTreeClassifier(criterion="entropy", max_depth = 4)
decisionTree # it shows the default parameters
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=4,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
decisionTree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=4,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
predTree = decisionTree.predict(X_test)

# %%
print (predTree [0:5])
print (y_test [0:5])
# Out:
# ['Good' 'Good' 'Good' 'Good' 'Good']
# ['Good' 'Good' 'Good' 'Good' 'Good']

# %%
#from sklearn import metrics
#import matplotlib.pyplot as plt
print("DecisionTrees's Accuracy: ", metrics.accuracy_score(y_test, predTree))
# Out:
# DecisionTrees's Accuracy:  0.9412403474903475

# %% [raw]
# #install if you have not already
# !conda install -c conda-forge pydotplus -y
# !conda install -c conda-forge python-graphviz -y

# %%
from sklearn.externals.six import StringIO
import pydotplus
import matplotlib.image as mpimg
from sklearn import tree
# %matplotlib inline

# %%
dot_data = StringIO()
filename = "decisionTree.png"
featureNames = df.columns[0:6]
targetNames = df["LONNSOMHET_PER_MND_TYPE"].unique().tolist() #my_data["Drug"].unique().tolist()
out=tree.export_graphviz(decisionTree,feature_names=featureNames, out_file=dot_data, class_names= np.unique(y_train), filled=True,  special_characters=True,rotate=False)  
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
graph.write_png(filename)
img = mpimg.imread(filename)
plt.figure(figsize=(100, 200))
plt.imshow(img,interpolation='nearest')

# %%
#F1-score
from sklearn.metrics import f1_score
f1_score(y_test, yhat, average='weighted')
# Out:
# 0.9188585989186426

# %%
#jaccard index
from sklearn.metrics import jaccard_similarity_score
jaccard_similarity_score(y_test, yhat)
# Out:
# 0.9314671814671814

# %% [markdown]
# <hr>

# %% [markdown]
# ## Support Vector Machine

# %% [markdown]
# <h4> Radial basis function kernel, or RBF kernel</h4>

# %%
from sklearn import svm
clf = svm.SVC(kernel='rbf')
clf.fit(X_train, y_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
yhat = clf.predict(X_test)
yhat [0:5]
# Out:
# array(['Good', 'Good', 'Good', 'Good', 'Good'], dtype=object)

# %%
# Evaluation
from sklearn.metrics import classification_report, confusion_matrix
import itertools

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
# Compute confusion matrix
cnf_matrix = confusion_matrix(y_test, yhat, labels=['Good','Bad'])
np.set_printoptions(precision=2)

print (classification_report(y_test, yhat))

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=['Good','Bad'],normalize= False,  title='Confusion matrix')
# Out:
#              precision    recall  f1-score   support
#
#         Bad       0.00      0.00      0.00       548
#        Good       0.93      1.00      0.97      7740
#
# avg / total       0.87      0.93      0.90      8288
#
# Confusion matrix, without normalization
# [[7740    0]
#  [ 548    0]]
# C:\Users\Alizamin\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
#F1-score
from sklearn.metrics import f1_score
f1_score(y_test, yhat, average='weighted')
# Out:
# C:\Users\Alizamin\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# 0.9019507849680048

# %%
#jaccard index
from sklearn.metrics import jaccard_similarity_score
jaccard_similarity_score(y_test, yhat)
# Out:
# 0.9338803088803089

# %%
#Linear model
clf2 = svm.SVC(kernel='linear')
clf2.fit(X_train, y_train) 
yhat2 = clf2.predict(X_test)
print("Avg F1-score: %.4f" % f1_score(y_test, yhat2, average='weighted'))
print("Jaccard score: %.4f" % jaccard_similarity_score(y_test, yhat2))
# Out:
# Avg F1-score: 0.9020
# Jaccard score: 0.9339
# C:\Users\Alizamin\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# We may these two as well (a bit heavy, takes time)

# %% [raw]
# # Polynomial model
# clf3 = svm.SVC(kernel='poly')
# clf3.fit(X_train, y_train)
# yhat3 = clf3.predict(X_test)
# print("Avg F1-score: %.4f" % f1_score(y_test, yhat3, average='weighted'))
# print("Jaccard score: %.4f" % jaccard_similarity_score(y_test, yhat3))

# %% [raw]
# # Sigmoid model
# clf4 = svm.SVC(kernel='sigmoid')
# clf4.fit(X_train, y_train)
# yhat4 = clf4.predict(X_test)
# print("Avg F1-score: %.4f" % f1_score(y_test, yhat4, average='weighted'))
# print("Jaccard score: %.4f" % jaccard_similarity_score(y_test, yhat4))

# %% [markdown]
# <hr>

# %% [markdown]
# <h2 style="color: green">4) Lag 5 features (nye kolonner med data basert på de du har) i databasen ved bruk av SQL </h2>
# 	- Lag, addisjon, avg, ..

# %%
data.columns
# Out:
# Index(['INSKUDD', 'UTLAN', 'PURRING_ANTALL_12MND', 'ALDER', 'KJONN',
#        'HAR_MOBIL', 'LONNSOMHET_PER_MND_TYPE'],
#       dtype='object')

# %%
#conn = sqlite3.connect('sparebank.db3')
#cursor = conn.cursor()

#unfortunately SQLite does not support complex queries, so have to run queries locally
myquery_1 ="SELECT INSKUDD, UTLAN, LONNSOMHET_PER_MND FROM TABELL_1"

myquery_2 ="ALTER TABLE TABELL_1 ADD ARLIG_LONNSOMHET AS (LONNSOMHET_PER_MND*12)"

myquery_3 ="ALTER TABLE TABELL_1 ADD CUSTOMER_TYPE AS CASE WHEN (LONNSOMHET_PER_MND > 0) THEN 'Good' WHEN (LONNSOMHET_PER_MND < 0) THEN 'Bad' END"

myquery_4 ="INSERT INTO sparebank.TABELL_1 (`INSKUDD`, `UTLAN`, `PURRING_ANTALL_12MND`,`ALDER`, `KJONN`, `HAR_MOBIL`,`LONNSOMHET_PER_MND_TYPE`) VALUES 'INSKUDD_EKS', 'UTLAN_EKS', 'PURRING_ANTALL_12MND_EKS', 'ALDER_EKS',  'KJONN_EKS', 'HAR_MOBIL_EKS', 'LONNSOMHET_PER_MND_TYPE_EKS"

myquery_5 ="SELECT TOP 50 PERCENT * FROM INSKUDD"

# Change the number beneath
cursor.execute(myquery_1)

myresult = cursor.fetchall()

for x in myresult:
  print(x)
# Out:
# (193, 720, 527)
# (339, 643, 1385)
# (0, 0, 11)
# (48, 0, 454)
# (231, 0, 127)
# (8, 0, 74)
# (0, 0, -36006)
# (310, 0, 592)
# (74, 1870, 529)
# (332, 0, 451)
# (39, 0, 69)
# (13, 0, 24)
# (312, 0, 300)
# (0, 0, -6)
# (178, 0, -70)
# (20, 0, 20)
# (4, 0, 177)
# (522, 0, 624)
# (0, 0, 0)
# (353, 0, 586)
# (21, 1345, 939)
# (214, 0, 435)
# (124, 0, 212)
# (2661, 0, 2257)
# (901, 0, 850)
# (0, 0, 0)
# (25, 0, 108)
# (100, 475, 656)
# (6, 0, 179)
# (5, 828, 658)
# (54, 1091, 2123)
# (0, 1271, 1350)
# (172, 0, 277)
# (29, 0, 47)
# (8, 3033, 3973)
# (331, 0, -213)
# (36, 0, 746)
# (9, 1508, 966)
# (37, 0, 92)
# (209, 0, 340)
# (169, 0, 149)
# (15, 0, 52)
# (532, 0, 935)
# (82, 559, 1390)
# (181, 3870, 3680)
# (194, 0, 348)
# (10, 0, 107)
# (20, 0, 35)
# (14, 0, 133)
# (13, 0, 78)
# (78, 5125, 1265)
# (62, 0, 88)
# (0, 353, 2440)
# (188, 1184, 1664)
# (36, 0, 88)
# (3, 1423, 1083)
# (18, 1699, 122)
# (160, 0, 58)
# (46, 661, 480)
# (14, 0, 15)
# (1, 18, 172)
# (241, 0, 463)
# ...

# %% [markdown]
# <hr>

# %% [markdown]
# # Example - Evaluation for Logistic if the data was divided into three. It would be ideal to have separate validation data

# %%
X_val
# Out:
# array([[-3.09e-01, -4.48e-01, -1.24e-01,  1.60e+00, -1.04e+00, -2.09e+00],
#        [-3.78e-01, -4.48e-01, -1.24e-01,  1.99e+00,  9.63e-01,  4.79e-01],
#        [-3.88e-01, -4.48e-01, -1.24e-01, -2.21e-01, -1.04e+00,  4.79e-01],
#        ...,
#        [ 5.79e-17, -6.02e-17, -1.24e-01,  8.36e-01, -1.04e+00,  4.79e-01],
#        [ 5.79e-17, -6.02e-17, -1.24e-01, -2.69e-01, -1.04e+00, -2.09e+00],
#        [ 7.63e-02, -4.48e-01, -1.24e-01,  4.04e-01,  9.63e-01, -2.09e+00]])

# %%
y_val
# Out:
# array(['Good', 'Good', 'Good', ..., 'Good', 'Good', 'Good'], dtype=object)

# %%
yhat_val = LR.predict(X_val)
yhat_prob_val = LR.predict_proba(X_val)
yhat_prob_val
# Out:
# array([[0.05, 0.95],
#        [0.04, 0.96],
#        [0.09, 0.91],
#        ...,
#        [0.04, 0.96],
#        [0.07, 0.93],
#        [0.07, 0.93]])

# %%
#Logistic Regression
yhat_val = LR.predict(X_val)
yhat_prob_val = LR.predict_proba(X_val)

#Jaccard index
LGR_jaccard = jaccard_similarity_score(y_val, yhat_val)
print("Logistic Regression - Jaccard score = " , LGR_jaccard)

#F1-score
LGR_f1_score = f1_score(y_val, yhat_val, average='weighted') 
print("Logistic Regression - F1-score = " , LGR_f1_score)

#LogLoss
LGR_log_loss = log_loss(y_val, yhat_prob_val)
print("Logistic Regression - LogLoss = " , LGR_log_loss)
# Out:
# Logistic Regression - Jaccard score =  0.9360482654600302
# Logistic Regression - F1-score =  0.9051286281466107
# Logistic Regression - LogLoss =  0.2166839646601121
# C:\Users\Alizamin\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# #### Out of X-values, we may map out customers with the highest profitability probability

# %%
for i in range(len(X_val)):
    print("X=%s, Predicted=%s" % (X_val[i],yhat_prob_val[i]))
# Out:
# X=[-0.31 -0.45 -0.12  1.6  -1.04 -2.09], Predicted=[0.05 0.95]
# X=[-0.38 -0.45 -0.12  1.99  0.96  0.48], Predicted=[0.04 0.96]
# X=[-0.39 -0.45 -0.12 -0.22 -1.04  0.48], Predicted=[0.09 0.91]
# X=[ 5.79e-17 -6.02e-17 -1.24e-01 -1.73e-01  9.63e-01  4.79e-01], Predicted=[0.07 0.93]
# X=[ 1.06  1.46 -0.12  0.02  0.96  0.48], Predicted=[0.02 0.98]
# X=[-0.39 -0.45 -0.12  0.07 -1.04  0.48], Predicted=[0.08 0.92]
# X=[-0.39 -0.38 -0.12  0.64  0.96  0.48], Predicted=[0.07 0.93]
# X=[-0.39 -0.14 -0.12 -0.17 -1.04  0.48], Predicted=[0.08 0.92]
# X=[ 0.46 -0.45 -0.12  2.18  0.96 -2.09], Predicted=[0.03 0.97]
# X=[-0.02 -0.45 -0.12 -0.27  0.96  0.48], Predicted=[0.08 0.92]
# X=[-0.29 -0.45 -0.12 -0.89 -1.04  0.48], Predicted=[0.11 0.89]
# X=[-0.06 -0.16 -0.12  0.6   0.96 -2.09], Predicted=[0.06 0.94]
# X=[-0.32 -0.45 -0.12 -0.94 -1.04  0.48], Predicted=[0.11 0.89]
# X=[ 0.06  6.99 -0.12 -0.17  0.96  0.48], Predicted=[0. 1.]
# X=[ 1.14  0.19 -0.12  0.02 -1.04  0.48], Predicted=[0.03 0.97]
# ...

# %% [markdown]
# <hr>

# %% [markdown]
# ### Save the data

# %%
data.to_csv('clean_data.csv')

# %% [markdown]
# ### Close the connection

# %%
conn.commit()
conn.close()
